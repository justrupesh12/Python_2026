# %% [markdown]
# 🎯 Set Types
# Set types represent unordered collections of unique items. They are useful for membership testing, removing duplicates, and performing mathematical set operations (like union, intersection, difference).
#
# 1. set
# Explanation: Sets are mutable (changeable), unordered collections of unique, hashable items. Hashable means the items must be immutable (like numbers, strings, tuples, but not lists or other sets). Sets are defined using curly braces {} or the set() constructor. An empty set must be created with set(), as {} creates an empty dictionary.

# %%
# key chars of set 

# unique ites only (no duplicates)

list = []
tuple1 = ()

# %%
number = {1, 2, 3, 2, 1, 4} 
number
# Out:
# {1, 2, 3, 4}

# %%
type(number)
# Out:
# set

# %%
fruits = {"apple", "banana", "cherry", "apple" ,"guava"}
fruits
# Out:
# {'apple', 'banana', 'cherry', 'guava'}

# %%
items  = {"apple", "banana", "cherry", "apple" ,"guava", 1, 2, 3, 2, 1, 4, True, 3.5, 4.5}
items
# Out:
# {1, 2, 3, 3.5, 4, 4.5, 'apple', 'banana', 'cherry', 'guava'}

# %%
my_set = {5,1,2,5,6,7,8}

# %%
my_set
# Out:
# {1, 2, 5, 6, 7, 8}

# %%
my_set[0]   # you cannot access itesm by index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 my_set[0]   # you cannot access itesm by index
#
# TypeError: 'set' object is not subscriptable

# %%
# Mutable (you can change it)

fruits = {"apple", "banana"}
fruits.add("orange")
fruits.remove("banana")
print(fruits)
# Out:
# {'orange', 'apple'}

# %%
# can only contain immutable(unchangeable) items 

# valid items in a set 

valid_set = { 2.5, "hello", True, (1,2)}
print(valid_set)
# Out:
# {'hello', 2.5, (1, 2), True}

# %%
# true :- 1 and False :- 0

# %%
# invalid = list are mutable (changable)

invalid_set = {1, 2,[3,4]}  # will give error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 # invalid = list are mutable (changable)
# ----> 3 invalid_set = {1, 2,[3,4]}  # will give error
#
# TypeError: unhashable type: 'list'

# %%
my_list = [] # mutable and slicing and indexing possible [Start, stop, step]

my_tuple = ()# immutable but slicing and indexing possible[start, stop, step] index and count methods available
my_set = {}# mutable but no slicing and indexing possible and unordered in nature. empty set declared like this will be dictionary

print(my_list)
print(type(my_list))

print(my_tuple)
print(type(my_tuple))

print(my_set)
print(type(my_set))
# Out:
# []
# <class 'list'>
# ()
# <class 'tuple'>
# {}
# <class 'dict'>

# %%
list=[1,2,3,4,5]
list
tup=(1,2,3,4,5)
print(type(list))
set1=set(list)
set1
print(type(set1))
set2=set(tup)
print(type(set2))
# Out:
# <class 'list'>
# <class 'set'>
# <class 'set'>

# %%
# creat set from a string

letters = set("hello")
print(letters)
print(type(letters))
# Out:
# {'l', 'h', 'e', 'o'}
# <class 'set'>

# %%
# changed list to tuple
numbers = set((1,2,3,4,5))
type(numbers)
print(numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
my_set = set()
type(my_set)
# Out:
# set

# %%
fruits = {"apple", "banana"}

# %%
fruits.add("orange")
fruits
# Out:
# {'apple', 'banana', 'orange'}

# %%
fruits.pop()
fruits
# Out:
# {'apple', 'banana'}

# %%
fruits.add("apple") # adding duplicate item will have no effect
fruits
# Out:
# {'apple', 'banana'}

# %%
#updated code after deletions
fruits
# Out:
# {'apple', 'banana'}

# %%
fruits.update({"mango", 'grape', 'kiwi'})
fruits
# Out:
# {'apple', 'banana', 'grape', 'kiwi', 'mango'}

# %%
fruits.update({"pear"})
fruits.update(("plum",))
print(fruits)
# Out:
# {'grape', 'plum', 'apple', 'banana', 'pear', 'kiwi', 'mango'}

# %%
fruits={'grape', 'plum', 'apple', 'banana', 'pear', 'kiwi', 'mango'}

# %%
fruits
# Out:
# {'apple', 'banana', 'grape', 'kiwi', 'mango', 'pear', 'plum'}

# %%
fruits.remove("banana")
fruits
# Out:
# {'apple', 'grape', 'kiwi', 'mango', 'pear', 'plum'}

# %%
fruits.clear()# clearing all items from set

# %%
fruits
# Out:
# set()

# %%
fruits={'apple', 'banana', 'grape', 'kiwi', 'mango', 'pear', 'plum'}

# %%
fruits
# Out:
# {'apple', 'banana', 'grape', 'kiwi', 'mango', 'pear', 'plum'}

# %%
fruits
# Out:
# set()

# %%
fruits={'apple', 'banana', 'grape', 'kiwi', 'mango', 'pear', 'plum'}

# %%
pavan_fruits = fruits.copy()

# %%
pavan_fruits
# Out:
# {'apple', 'banana', 'grape', 'kiwi', 'mango', 'pear', 'plum'}

# %%
id(fruits)
# Out:
# 2030850796320

# %%
id(pavan_fruits)
# Out:
# 2030850800128

# %%
b=fruits

# %%
id(b)
# Out:
# 2030850796320

# %%
colors = {"red", "green", "blue", "yellow"}
print(colors)
colors.discard("green")
print(colors)
# Out:
# {'blue', 'yellow', 'green', 'red'}
# {'blue', 'yellow', 'red'}

# %%
colors.discard("red")  # removing an item that is not present does not raise an error
print(colors)
# Out:
# {'blue', 'yellow'}

# %%
colors.discard("red")  # removing an item that is not present does not raise an error
print(colors)
# Out:
# {'blue', 'yellow'}

# %%
numbers = {1,2,3,4,5}
removed = numbers.pop()


print(f"Removed: {removed}")
print(f"Remaining: {numbers}")
# Out:
# Removed: 1
# Remaining: {2, 3, 4, 5}

# %%
numbers = {1,2,3,4,5}
removed = numbers.pop()
print(f"Removed: {removed}")
# Out:
# Removed: 1

# %%
numbers = {1,2,3,4,5}
removed = numbers.pop(1)
print(f"Removed: {removed}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 2
#       1 numbers = {1,2,3,4,5}
# ----> 2 removed = numbers.pop(1)
#       3 print(f"Removed: {removed}")
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
list = [1,2,3,4,5]
list.pop()
print(list)
# Out:
# [1, 2, 3, 4]

# %%
list = [1,2,3,4,5]
list.pop(0)
print(list)
# Out:
# [2, 3, 4, 5]

# %%
fruits = {'apple', 'banana', 'kiwi'}
fruits
# Out:
# {'apple', 'banana', 'kiwi'}

# %%
"apple" in fruits
# Out:
# True

# %%
"apple" not in fruits
# Out:
# False

# %%
## getting set size 

numbers = {1,2,3,4,5}
numbers
# Out:
# {1, 2, 3, 4, 5}

# %%
len(numbers)
# Out:
# 5

# %%
import keyword
kwlist = keyword.kwlist
kwlist
len(kwlist)
# Out:
# 35

# %%
# looping through sets 

fruits_list = ['apple', 'banana', 'grape', 'kiwi', 'mango', 'pear', 'plum']

# %%
for i in fruits_list:
    print(i)
# Out:
# apple
# banana
# grape
# kiwi
# mango
# pear
# plum

# %%
set_a = {1,2,3,4}
set_b = {3,4,5,6}

# %%
set_a|set_b # union of two sets
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set_a.union(set_b)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set_a.intersection(set_b) # common items in both sets
# Out:
# {3, 4}

# %%
set_a&set_b
# Out:
# {3, 4}

# %%
set_a.intersection_update(set_b)
print(set_a)
# Out:
# {3, 4}

# %%
set_a
set_b
# Out:
# {3, 4, 5, 6}

# %%
Pavan={1,2,3,4,5,6}
Abhi={5,6,7,8,9,10}


new_set=Pavan.intersection(Abhi)
new_set
# Out:
# {5, 6}

# %%
print(Pavan)
print(Abhi)
print(new_set)
# Out:
# {1, 2, 3, 4, 5, 6}
# {5, 6, 7, 8, 9, 10}
# {5, 6}

# %%
Pavan={1,2,3,4,5,6}
Abhi={5,6,7,8,9,10}
Rupesh={6,7,8,9,10,11,1}

Pavan.intersection_update(Abhi)

# %%
print(Pavan)
print(Abhi)
print(Rupesh)
# Out:
# {5, 6}
# {5, 6, 7, 8, 9, 10}
# {1, 6, 7, 8, 9, 10, 11}

# %%
Abhi.intersection_update(Rupesh)

# %%
print(Pavan)
print(Abhi)
print(Rupesh)
# Out:
# {5, 6}
# {6, 7, 8, 9, 10}
# {1, 6, 7, 8, 9, 10, 11}

# %%
Rupesh.intersection_update(Pavan)

# %%
print(Pavan)
print(Abhi)
print(Rupesh)
# Out:
# {5, 6}
# {6, 7, 8, 9, 10}
# {6}

# %%
a={1,6}
b=(1,2,3,4,5)

a.issubset(b)
# Out:
# False

# %%
# Disjoint Set this means no  common items between two sets
a={1,2,3}
b={4,5,6}
a.isdisjoint(b)
# Out:
# True

# %%
### creating a frozenset 

frozen = frozenset([1,2,3,4,5,1,2,3])
print(frozen)
# Out:
# frozenset({1, 2, 3, 4, 5})

# %%
# you cnnot modify it 
frozen.add(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 2
#       1 # you cnnot modify it
# ----> 2 frozen.add(6)
#
# AttributeError: 'frozenset' object has no attribute 'add'
